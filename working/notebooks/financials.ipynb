# %%
import os
import pandas as pd

# %%
ticker = "AAPL"

cwd = os.getcwd()

csv_path = os.path.join(cwd, "..", "..", "tickers", ticker, "financials_2025-05-25.csv")
csv_path = os.path.abspath(csv_path)

df = pd.read_csv(csv_path)
df
# Out:
#     dimension calendardate     datekey reportperiod fiscalperiod  \
# 0         ARQ   1993-12-31  1994-01-26   1993-12-31      1994-Q1
# 1         ARQ   1994-06-30  1994-08-12   1994-07-01      1994-Q3
# 2         ARQ   1994-09-30  1994-12-13   1994-09-30      1994-Q4
# 3         ARQ   1994-12-31  1995-02-09   1994-12-30      1995-Q1
# 4         ARQ   1995-03-31  1995-05-15   1995-03-31      1995-Q2
# ..        ...          ...         ...          ...          ...
# 566       MRY   2020-12-31  2020-09-26   2020-09-26      2020-FY
# 567       MRY   2021-12-31  2021-09-25   2021-09-25      2021-FY
# 568       MRY   2022-12-31  2022-09-24   2022-09-24      2022-FY
# 569       MRY   2023-12-31  2023-09-30   2023-09-30      2023-FY
# 570       MRY   2024-12-31  2024-09-28   2024-09-28      2024-FY
#
#      workingcapital     marketcap lastupdated        accoci        assets  \
# 0      1.879846e+09  3.926233e+09  2025-05-02 -2.650900e+07  5.042440e+09
# ...
